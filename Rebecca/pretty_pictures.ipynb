# %%
# %matplotlib notebook
import numpy as np
from astropy.io import fits
import matplotlib.pyplot as plt
from astropy.visualization import make_lupton_rgb
from matplotlib.colors import LogNorm

# %%
# file read-in
b_loc = 'h_m51_b_s05_drz_sci.fits'
v_loc = 'h_m51_v_s05_drz_sci.fits'
i_loc = 'h_m51_i_s05_drz_sci.fits'
h_loc = 'h_m51_h_s05_drz_sci.fits'

b_fits = fits.open(b_loc)
v_fits = fits.open(v_loc)
i_fits = fits.open(i_loc)
h_fits = fits.open(h_loc)

# %%
b_fits.info()
# Out:
# Filename: h_m51_b_s05_drz_sci.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU    1762   (8600, 12200)   float32

# %%
#thomas's function
def plot_image(a,figsize=(10,10), cmap='binary_r'):
    plt.figure(figsize=figsize)
    plt.imshow(a, vmin=np.percentile(a, 5), vmax=np.percentile(a, 98),
               origin='lower', cmap=cmap, interpolation='nearest')

# %%
# normalize by dividing by median or avg ?

#make_lupton_rgb(5*filts[3], 10*filts[1], 10*filts[2], stretch=5)
rgb = make_lupton_rgb(5*i_fits[0].data, 10*v_fits[0].data, 10*b_fits[0].data, Q=10, stretch=5)

# %%
plt.figure(figsize=[5,10])
plt.imshow(rgb, norm=LogNorm(vmin=200), cmap='rainbow')
plt.axis('off')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="500">

# %%
#clip edges eventually
# how to get 4th image on? can at least try different combos of 3 filters
